# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from nltk import FreqDist
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
import re
import matplotlib.pyplot as plt
from nltk.tokenize import RegexpTokenizer
from gensim.parsing.preprocessing import remove_stopwords

# %%
fake = pd.read_csv("dataset/Fake.csv")
true = pd.read_csv("dataset/True.csv")

# %%
textfake = " ".join(text for text in fake.text)
textreal = " ".join(text for text in true.text)
tokenizer = RegexpTokenizer(r'\w+')
tokensfake = tokenizer.tokenize(textfake)
tokensreal = tokenizer.tokenize(textreal)
freqf = FreqDist(textfake)
freqr = FreqDist(textreal)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
fake_words = [word.lower() for word in fake_words]
fake_words = [word for word in fake_words if word.lower() in remove_stopwords(word.lower())]
stopwords = set(STOPWORDS)

# %%
wordcloud = WordCloud(background_color="white").generate(textfake)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
wordcloud = WordCloud(background_color="white").generate(textreal)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
true['target']=['True']*len(true)
fake['target']=['Fake']*len(fake)

# %%
data=true.append(fake).sample(frac=1).reset_index().drop(columns=['index'])
data.head()
# Out:
#                                                title  \
# 0   Muslims Raise $20,000 In THREE HOURS To Fix V...
# 1  U.S. State Dept cites standard practice in res...
# 2   ICYMI: SNL Skewers “Morning Joe” And It Is Hi...
# 3  LAME DUCK: New Obama Executive Action Opens Do...
# 4  (VIDEO) RIOTERS TAKE SELFIES WITH TORCHED POLI...
#
#                                                 text          subject  \
# 0  Ever since Donald Trump was elected by a minor...             News
# 1  WASHINGTON (Reuters) - The U.S. State Departme...     politicsNews
# 2  This week s cold open for Saturday Night Live ...             News
# 3  Patrick Henningsen 21st Century Wire As 21WIRE...      Middle-east
# 4                                                     Government News
#
#                 date target
# 0  February 21, 2017   Fake
# 1  January 26, 2017    True
# 2        May 7, 2017   Fake
# 3   December 8, 2016   Fake
# 4       Apr 27, 2015   Fake

# %%
#data.to_hdf("combined2.h5", 'data', mode='w', format='table')
store = data.to_pickle('dataset/combined_data')
